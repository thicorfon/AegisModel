# %%
import pandas as pd
import os

# %%
our_data_root = './../Our Data/'

# %%
list_of_sessions = next(os.walk(our_data_root))[1]

# %%
list_of_sensors = ['Accelerometer',
                  'Gyroscope',
                  'Magnetometer',
                  'KeyPressEvent',
                  'KeyboardTouchEvent']

# %%
columns = {'Accelerometer':['Systime','EventTime','ActivityID','X','Y','Z','Phone_orientation'],
           'Gyroscope':['Systime','EventTime','ActivityID','X','Y','Z','Phone_orientation'],
           'Magnetometer':['Systime','EventTime','ActivityID','X','Y','Z','Phone_orientation'],
           'KeyboardTouchEvent':['Systime','EventTime','ActivityID','Pointer_count','PointerID','ActionID','X','Y','Pressure','Contact_size','Phone_orientation'],
           'KeyPressEvent':['Systime','PressTime','PressType','ActivityID','KeyID','Phone_orientation']}

# %%
accelerometer = pd.DataFrame(columns=columns['Accelerometer'])
for session in list_of_sessions:
    accelerometer = accelerometer.append(pd.read_csv(our_data_root+session+'/Accelerometer.csv',names=columns['Accelerometer']))
accelerometer.to_csv(our_data_root+'Accelerometer.csv')
gyroscope = pd.DataFrame(columns=columns['Gyroscope'])
for session in list_of_sessions:
    gyroscope = gyroscope.append(pd.read_csv(our_data_root+session+'/Gyroscope.csv',names=columns['Gyroscope']))
gyroscope.to_csv(our_data_root+'Gyroscope.csv')
Magnetometer = pd.DataFrame(columns=columns['Magnetometer'])
for session in list_of_sessions:
    Magnetometer = Magnetometer.append(pd.read_csv(our_data_root+session+'/Magnetometer.csv',names=columns['Magnetometer']))
Magnetometer.to_csv(our_data_root+'Magnetometer.csv')
KeyboardTouchEvent = pd.DataFrame(columns=columns['KeyboardTouchEvent'])
for session in list_of_sessions:
    KeyboardTouchEvent = KeyboardTouchEvent.append(pd.read_csv(our_data_root+session+'/KeyboardTouchEvent.csv',names=columns['KeyboardTouchEvent']))
KeyboardTouchEvent.to_csv(our_data_root+'KeyboardTouchEvent.csv')
KeyPressEvent = pd.DataFrame(columns=columns['KeyPressEvent'])
for session in list_of_sessions:
    KeyPressEvent = KeyPressEvent.append(pd.read_csv(our_data_root+session+'/KeyPressEvent.csv',names=columns['KeyPressEvent']))
KeyPressEvent.to_csv(our_data_root+'KeyPressEvent.csv')

# %%
accelerometer.ActivityID.unique()
# Out:
# array(['Jo1', 'Diego01', 'Toto10', 'Toto8', 'Toto1', 'Toto6', 'Toto7',
#        'Toto9', 'jo3', 'jo4', 'jo5', 'jo2', 'Diego05', 'Diego02',
#        'Diego03', 'Diego04', 'Toto5', 'Toto2', 'Andres1'], dtype=object)

# %%
accelerometer = pd.DataFrame(columns=columns['Accelerometer'])

# %%
pd.read_csv(our_data_root+'/Accelerometer.csv')
# Out:
#         Unnamed: 0        Systime         EventTime ActivityID         X  \
# 0                0  1537190593299  1164647485827270        Jo1 -0.225055
# 1                1  1537190593300  1164647505795270        Jo1 -0.028730
# 2                2  1537190593301  1164647525747270        Jo1 -0.014365
# 3                3  1537190593301  1164647545715270        Jo1  0.067038
# 4                4  1537190593302  1164647565667270        Jo1 -0.023942
# 5                5  1537190593303  1164647585667270        Jo1  0.162806
# 6                6  1537190593304  1164647605619270        Jo1  0.124498
# 7                7  1537190593304  1164647625587270        Jo1  0.397437
# 8                8  1537190593305  1164647645539270        Jo1  0.229843
# 9                9  1537190593305  1164647665507270        Jo1  0.445322
# 10              10  1537190593495  1164647685459270        Jo1 -0.981623
# 11              11  1537190593496  1164647705427270        Jo1 -0.014365
# 12              12  1537190593497  1164647725395270        Jo1 -0.047884
# 13              13  1537190593498  1164647745347270        Jo1 -0.258574
# 14              14  1537190593498  1164647765315270        Jo1 -0.110133
# 15              15  1537190593499  1164647785267270        Jo1 -0.043096
# 16              16  1537190593500  1164647805267270        Jo1  0.541090
# 17              17  1537190593500  1164647825219270        Jo1 -0.052672
# 18              18  1537190593501  1164647845187270        Jo1 -0.052672
# 19              19  1537190593501  1164647865139270        Jo1 -0.526724
# 20              20  1537190593695  1164647885107270        Jo1  0.445322
# 21              21  1537190593696  1164647905059270        Jo1  0.703895
# 22              22  1537190593697  1164647925027270        Jo1  0.090980
# 23              23  1537190593698  1164647944995270        Jo1 -0.282516
# 24              24  1537190593699  1164647964947270        Jo1 -0.574608
# 25              25  1537190593699  1164647984915270        Jo1 -0.804452
# 26              26  1537190593700  1164648004867270        Jo1 -0.794875
# 27              27  1537190593700  1164648024867270        Jo1 -0.632069
# 28              28  1537190593701  1164648044819270        Jo1 -0.622492
# 29              29  1537190593702  1164648064787270        Jo1 -0.555455
# ...            ...            ...               ...        ...       ...
# 301672        3126  1541942076634  5916141136585153    Andres1 -0.770933
# 301673        3127  1541942076833  5916141336249153    Andres1 -0.919373
# 301674        3128  1541942077031  5916141535897153    Andres1 -0.909797
# 301675        3129  1541942077229  5916141735561153    Andres1 -0.852336
# 301676        3130  1541942077429  5916141935193153    Andres1 -0.852336
# 301677        3131  1541942077629  5916142134857153    Andres1 -0.924162
# 301678        3132  1541942077828  5916142334537153    Andres1 -0.890643
# 301679        3133  1541942078027  5916142534169153    Andres1 -1.019930
# 301680        3134  1541942078227  5916142733833153    Andres1 -0.924162
# 301681        3135  1541942078427  5916142933465153    Andres1 -1.072602
# 301682        3136  1541942078628  5916143133129153    Andres1 -1.110910
# 301683        3137  1541942078826  5916143332777153    Andres1 -1.082179
# 301684        3138  1541942079029  5916143532441153    Andres1 -1.091756
# 301685        3139  1541942079228  5916143732073153    Andres1 -1.010353
# 301686        3140  1541942079426  5916143931753153    Andres1 -0.981623
# 301687        3141  1541942079626  5916144131385153    Andres1 -0.828394
# 301688        3142  1541942079826  5916144331049153    Andres1 -0.909797
# 301689        3143  1541942080025  5916144530681153    Andres1 -1.000776
# 301690        3144  1541942080225  5916144730361153    Andres1 -1.029507
# 301691        3145  1541942080425  5916144929993153    Andres1 -0.876278
# 301692        3146  1541942080624  5916145129657153    Andres1 -0.948104
# 301693        3147  1541942080826  5916145329321153    Andres1 -0.895431
# 301694        3148  1541942081023  5916145528969153    Andres1 -0.885855
# 301695        3149  1541942081226  5916145728633153    Andres1 -0.943315
# 301696        3150  1541942081422  5916145928265153    Andres1 -0.881066
# 301697        3151  1541942081623  5916146127929153    Andres1 -0.900220
# 301698        3152  1541942081822  5916146327577153    Andres1 -0.852336
# 301699        3153  1541942082024  5916146527241153    Andres1 -0.866701
# 301700        3154  1541942082223  5916146726873153    Andres1 -0.972046
# 301701        3155  1541942082422  5916146926537153    Andres1 -1.225831
#
#                Y         Z  Phone_orientation
# 0       5.477933  7.800309                  0
# 1       5.516241  8.240842                  0
# 2       5.951985  7.900866                  0
# 3       5.717354  7.240066                  0
# 4       5.032612  7.469909                  0
# 5       5.468357  8.470686                  0
# 6       5.894525  8.164227                  0
# 7       5.439626  7.671022                  0
# 8       6.066907  7.388506                  0
# 9       5.966351  7.939173                  0
# 10      6.229713  8.188170                  0
# 11      5.932832  8.599973                  0
# 12      5.382165  8.360553                  0
# 13      5.027823  8.274361                  0
# 14      5.861006  8.216900                  0
# 15      6.406884  8.432379                  0
# 16      4.812346  9.466674                  0
# 17      4.620809  9.457097                  0
# 18      5.425261  8.192958                  0
# 19      5.190630  7.321469                  0
# 20      5.185841  7.268796                  0
# 21      4.663905  7.240066                  0
# 22      4.654328  7.206547                  0
# 23      5.085284  8.025364                  0
# 24      5.142745  9.605537                  0
# 25      5.219360  9.964667                  0
# 26      5.391742  9.538500                  0
# 27      5.114015  8.949526                  0
# 28      5.075707  8.236053                  0
# 29      5.243302  7.991845                  0
# ...          ...       ...                ...
# 301672  7.546524  6.536170                  0
# 301673  7.599196  6.464345                  0
# 301674  7.532158  6.215348                  0
# 301675  7.455544  6.354211                  0
# 301676  7.402872  6.263232                  0
# 301677  7.536947  6.119579                  0
# 301678  7.489063  6.172252                  0
# 301679  7.594408  6.306327                  0
# 301680  7.541735  6.277597                  0
# 301681  7.527370  6.622362                  0
# 301682  7.493851  6.789956                  0
# 301683  7.580042  6.751649                  0
# 301684  7.575254  6.976704                  0
# 301685  7.690176  6.359000                  0
# 301686  7.460332  6.507440                  0
# 301687  7.316680  6.502652                  0
# 301688  7.431602  6.469133                  0
# 301689  7.474698  6.421249                  0
# 301690  7.584831  6.421249                  0
# 301691  7.292738  6.483498                  0
# 301692  7.498640  6.339846                  0
# 301693  7.398083  6.402095                  0
# 301694  7.398083  6.569689                  0
# 301695  7.326257  6.732495                  0
# 301696  7.350199  6.612785                  0
# 301697  7.388506  6.435614                  0
# 301698  7.378930  6.426037                  0
# 301699  7.350199  6.464345                  0
# 301700  7.436390  6.306327                  0
# 301701  7.570466  6.440403                  0
#
# [301702 rows x 8 columns]
