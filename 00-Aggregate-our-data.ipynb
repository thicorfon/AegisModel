# %%
import pandas as pd
import os

# %%
our_data_root = './../Our Data/'

# %%
list_of_sessions = next(os.walk(our_data_root))[1]

# %%
list_of_sensors = ['Accelerometer',
                  'Gyroscope',
                  'Magnetometer',
                  'KeyPressEvent',
                  'KeyboardTouchEvent']

# %%
columns = {'Accelerometer':['Systime','EventTime','ActivityID','X','Y','Z','Phone_orientation'],
           'Gyroscope':['Systime','EventTime','ActivityID','X','Y','Z','Phone_orientation'],
           'Magnetometer':['Systime','EventTime','ActivityID','X','Y','Z','Phone_orientation'],
           'KeyboardTouchEvent':['Systime','EventTime','ActivityID','Pointer_count','PointerID','ActionID','X','Y','Pressure','Contact_size','Phone_orientation'],
           'KeyPressEvent':['Systime','PressTime','PressType','ActivityID','KeyID','Phone_orientation']}

# %%
accelerometer = pd.DataFrame(columns=columns['Accelerometer'])
for session in list_of_sessions:
    accelerometer = accelerometer.append(pd.read_csv(our_data_root+session+'/Accelerometer.csv',names=columns['Accelerometer']))
accelerometer.to_csv(our_data_root+'Accelerometer.csv')
gyroscope = pd.DataFrame(columns=columns['Gyroscope'])
for session in list_of_sessions:
    gyroscope = gyroscope.append(pd.read_csv(our_data_root+session+'/Gyroscope.csv',names=columns['Gyroscope']))
gyroscope.to_csv(our_data_root+'Gyroscope.csv')
Magnetometer = pd.DataFrame(columns=columns['Magnetometer'])
for session in list_of_sessions:
    Magnetometer = Magnetometer.append(pd.read_csv(our_data_root+session+'/Magnetometer.csv',names=columns['Magnetometer']))
Magnetometer.to_csv(our_data_root+'Magnetometer.csv')
KeyboardTouchEvent = pd.DataFrame(columns=columns['KeyboardTouchEvent'])
for session in list_of_sessions:
    KeyboardTouchEvent = KeyboardTouchEvent.append(pd.read_csv(our_data_root+session+'/KeyboardTouchEvent.csv',names=columns['KeyboardTouchEvent']))
KeyboardTouchEvent.to_csv(our_data_root+'KeyboardTouchEvent.csv')
KeyPressEvent = pd.DataFrame(columns=columns['KeyPressEvent'])
for session in list_of_sessions:
    KeyPressEvent = KeyPressEvent.append(pd.read_csv(our_data_root+session+'/KeyPressEvent.csv',names=columns['KeyPressEvent']))
KeyPressEvent.to_csv(our_data_root+'KeyPressEvent.csv')

# %%
accelerometer.ActivityID.unique()
# Out:
# array(['jo9', 'jo7', 'oscar1', 'Jo1', 'jo6', 'jo8', 'Diego01', 'Diego06',
#        'Toto10', 'Diego07', 'Toto8', 'Toto1', 'Toto6', 'Toto7', 'Toto9',
#        'jo3', 'jo4', 'jo5', 'jo2', 'Diego05', 'Diego02', 'Pedro1',
#        'Diego03', 'Diego04', 'Carlos1', 'Toto5', 'Toto2', 'Andres1'], dtype=object)

# %%
accelerometer = pd.DataFrame(columns=columns['Accelerometer'])

# %%
pd.read_csv(our_data_root+'/Accelerometer.csv')
# Out:
#         Unnamed: 0        Systime         EventTime ActivityID         X  \
# 0                0  1542583362262   280821978992709        jo9 -0.033519
# 1                1  1542583362263   280821998992709        jo9 -0.177171
# 2                2  1542583362264   280822018944709        jo9 -0.330400
# 3                3  1542583362265   280822038912709        jo9 -0.483629
# 4                4  1542583362266   280822058864709        jo9 -0.383072
# 5                5  1542583362267   280822078832709        jo9 -0.325611
# 6                6  1542583362268   280822098800709        jo9 -0.177171
# 7                7  1542583362269   280822118784709        jo9  0.043096
# 8                8  1542583362402   280822138752709        jo9 -0.071826
# 9                9  1542583362403   280822158704709        jo9 -0.138864
# 10              10  1542583362404   280822178672709        jo9 -0.186748
# 11              11  1542583362405   280822198624709        jo9 -0.201113
# 12              12  1542583362406   280822218592709        jo9 -0.383072
# 13              13  1542583362408   280822238576709        jo9 -0.483629
# 14              14  1542583362410   280822258544709        jo9 -0.330400
# 15              15  1542583362411   280822278496709        jo9 -0.129287
# 16              16  1542583362411   280822298464709        jo9  0.067038
# 17              17  1542583362419   280822318416709        jo9  0.134075
# 18              18  1542583362602   280822338384709        jo9  0.000000
# 19              19  1542583362603   280822358368709        jo9 -0.186748
# 20              20  1542583362604   280822378336709        jo9 -0.301669
# 21              21  1542583362604   280822398288709        jo9 -0.459687
# 22              22  1542583362605   280822418256709        jo9 -0.426168
# 23              23  1542583362606   280822438224709        jo9 -0.330400
# 24              24  1542583362607   280822458208709        jo9 -0.062249
# 25              25  1542583362608   280822478176709        jo9  0.062249
# 26              26  1542583362609   280822498128709        jo9  0.081403
# 27              27  1542583362619   280822518096709        jo9 -0.052672
# 28              28  1542583362801   280822538048709        jo9 -0.205901
# 29              29  1542583362802   280822558016709        jo9 -0.316035
# ...            ...            ...               ...        ...       ...
# 496322        3126  1541942076634  5916141136585153    Andres1 -0.770933
# 496323        3127  1541942076833  5916141336249153    Andres1 -0.919373
# 496324        3128  1541942077031  5916141535897153    Andres1 -0.909797
# 496325        3129  1541942077229  5916141735561153    Andres1 -0.852336
# 496326        3130  1541942077429  5916141935193153    Andres1 -0.852336
# 496327        3131  1541942077629  5916142134857153    Andres1 -0.924162
# 496328        3132  1541942077828  5916142334537153    Andres1 -0.890643
# 496329        3133  1541942078027  5916142534169153    Andres1 -1.019930
# 496330        3134  1541942078227  5916142733833153    Andres1 -0.924162
# 496331        3135  1541942078427  5916142933465153    Andres1 -1.072602
# 496332        3136  1541942078628  5916143133129153    Andres1 -1.110910
# 496333        3137  1541942078826  5916143332777153    Andres1 -1.082179
# 496334        3138  1541942079029  5916143532441153    Andres1 -1.091756
# 496335        3139  1541942079228  5916143732073153    Andres1 -1.010353
# 496336        3140  1541942079426  5916143931753153    Andres1 -0.981623
# 496337        3141  1541942079626  5916144131385153    Andres1 -0.828394
# 496338        3142  1541942079826  5916144331049153    Andres1 -0.909797
# 496339        3143  1541942080025  5916144530681153    Andres1 -1.000776
# 496340        3144  1541942080225  5916144730361153    Andres1 -1.029507
# 496341        3145  1541942080425  5916144929993153    Andres1 -0.876278
# 496342        3146  1541942080624  5916145129657153    Andres1 -0.948104
# 496343        3147  1541942080826  5916145329321153    Andres1 -0.895431
# 496344        3148  1541942081023  5916145528969153    Andres1 -0.885855
# 496345        3149  1541942081226  5916145728633153    Andres1 -0.943315
# 496346        3150  1541942081422  5916145928265153    Andres1 -0.881066
# 496347        3151  1541942081623  5916146127929153    Andres1 -0.900220
# 496348        3152  1541942081822  5916146327577153    Andres1 -0.852336
# 496349        3153  1541942082024  5916146527241153    Andres1 -0.866701
# 496350        3154  1541942082223  5916146726873153    Andres1 -0.972046
# 496351        3155  1541942082422  5916146926537153    Andres1 -1.225831
#
#                Y         Z  Phone_orientation
# 0       6.086061  7.613562                  0
# 1       6.110003  7.886500                  0
# 2       6.148310  8.020576                  0
# 3       6.100426  7.508216                  0
# 4       5.597643  7.666234                  0
# 5       5.635951  8.183381                  0
# 6       5.712565  8.269572                  0
# 7       5.779603  8.015787                  0
# 8       5.971139  7.982268                  0
# 9       6.157887  7.766790                  0
# 10      6.177041  7.867347                  0
# 11      6.105214  7.819463                  0
# 12      6.033388  7.886500                  0
# 13      5.731719  8.212111                  0
# 14      5.640739  8.092401                  0
# 15      5.583278  7.958326                  0
# 16      5.832275  7.819463                  0
# 17      5.980716  7.671022                  0
# 18      6.186617  7.872135                  0
# 19      6.143522  7.881712                  0
# 20      5.999869  7.838616                  0
# 21      6.042965  7.915231                  0
# 22      5.832275  7.891289                  0
# 23      5.698200  7.867347                  0
# 24      5.674258  7.948749                  0
# 25      5.784391  8.169016                  0
# 26      5.956774  7.733272                  0
# 27      6.038176  7.618350                  0
# 28      6.210559  7.685388                  0
# 29      6.143522  7.766790                  0
# ...          ...       ...                ...
# 496322  7.546524  6.536170                  0
# 496323  7.599196  6.464345                  0
# 496324  7.532158  6.215348                  0
# 496325  7.455544  6.354211                  0
# 496326  7.402872  6.263232                  0
# 496327  7.536947  6.119579                  0
# 496328  7.489063  6.172252                  0
# 496329  7.594408  6.306327                  0
# 496330  7.541735  6.277597                  0
# 496331  7.527370  6.622362                  0
# 496332  7.493851  6.789956                  0
# 496333  7.580042  6.751649                  0
# 496334  7.575254  6.976704                  0
# 496335  7.690176  6.359000                  0
# 496336  7.460332  6.507440                  0
# 496337  7.316680  6.502652                  0
# 496338  7.431602  6.469133                  0
# 496339  7.474698  6.421249                  0
# 496340  7.584831  6.421249                  0
# 496341  7.292738  6.483498                  0
# 496342  7.498640  6.339846                  0
# 496343  7.398083  6.402095                  0
# 496344  7.398083  6.569689                  0
# 496345  7.326257  6.732495                  0
# 496346  7.350199  6.612785                  0
# 496347  7.388506  6.435614                  0
# 496348  7.378930  6.426037                  0
# 496349  7.350199  6.464345                  0
# 496350  7.436390  6.306327                  0
# 496351  7.570466  6.440403                  0
#
# [496352 rows x 8 columns]
