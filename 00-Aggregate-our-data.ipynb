# %%
import pandas as pd
import os

# %%
our_data_root = './../Our Data/'

# %%
list_of_sessions = next(os.walk(our_data_root))[1]

# %%
list_of_sensors = ['Accelerometer',
                  'Gyroscope',
                  'Magnetometer',
                  'KeyPressEvent',
                  'KeyboardTouchEvent']

# %%
columns = {'Accelerometer':['Systime','EventTime','ActivityID','X','Y','Z','Phone_orientation'],
           'Gyroscope':['Systime','EventTime','ActivityID','X','Y','Z','Phone_orientation'],
           'Magnetometer':['Systime','EventTime','ActivityID','X','Y','Z','Phone_orientation'],
           'KeyboardTouchEvent':['Systime','EventTime','ActivityID','Pointer_count','PointerID','ActionID','X','Y','Pressure','Contact_size','Phone_orientation'],
           'KeyPressEvent':['Systime','PressTime','PressType','ActivityID','KeyID','Phone_orientation']}

# %%
accelerometer = pd.DataFrame(columns=columns['Accelerometer'])
for session in list_of_sessions:
    accelerometer = accelerometer.append(pd.read_csv(our_data_root+session+'/Accelerometer.csv',names=columns['Accelerometer']))
accelerometer.to_csv(our_data_root+'Accelerometer.csv')
gyroscope = pd.DataFrame(columns=columns['Gyroscope'])
for session in list_of_sessions:
    gyroscope = gyroscope.append(pd.read_csv(our_data_root+session+'/Gyroscope.csv',names=columns['Gyroscope']))
gyroscope.to_csv(our_data_root+'Gyroscope.csv')
Magnetometer = pd.DataFrame(columns=columns['Magnetometer'])
for session in list_of_sessions:
    Magnetometer = Magnetometer.append(pd.read_csv(our_data_root+session+'/Magnetometer.csv',names=columns['Magnetometer']))
Magnetometer.to_csv(our_data_root+'Magnetometer.csv')
KeyboardTouchEvent = pd.DataFrame(columns=columns['KeyboardTouchEvent'])
for session in list_of_sessions:
    KeyboardTouchEvent = KeyboardTouchEvent.append(pd.read_csv(our_data_root+session+'/KeyboardTouchEvent.csv',names=columns['KeyboardTouchEvent']))
KeyboardTouchEvent.to_csv(our_data_root+'KeyboardTouchEvent.csv')
KeyPressEvent = pd.DataFrame(columns=columns['KeyPressEvent'])
for session in list_of_sessions:
    KeyPressEvent = KeyPressEvent.append(pd.read_csv(our_data_root+session+'/KeyPressEvent.csv',names=columns['KeyPressEvent']))
KeyPressEvent.to_csv(our_data_root+'KeyPressEvent.csv')

# %%
accelerometer.ActivityID.unique()
# Out:
# array(['jo10', 'jo9', 'jo7', 'oscar1', 'Jo1', 'jo6', 'jo8', 'Toto11',
#        'Diego08', 'Diego01', 'Diego06', 'Toto10', 'Diego07', 'Diego09',
#        'Toto8', 'Toto1', 'Toto6', 'Toto7', 'Toto9', 'Diego10', 'jo3',
#        'jo4', 'jo5', 'jo2', 'Diego05', 'Diego02', 'Pedro1', 'Toto12',
#        'Diego03', 'Diego04', 'Carlos1', 'Toto5', 'Toto2', 'Andres1'], dtype=object)

# %%
accelerometer = pd.DataFrame(columns=columns['Accelerometer'])

# %%
pd.read_csv(our_data_root+'/Accelerometer.csv')
# Out:
#         Unnamed: 0        Systime         EventTime ActivityID         X  \
# 0                0  1542595217886   292677679831619       jo10 -0.368707
# 1                1  1542595217887   292677699783619       jo10 -0.517148
# 2                2  1542595217965   292677719751619       jo10 -0.445322
# 3                3  1542595217966   292677739719619       jo10 -0.488417
# 4                4  1542595217967   292677759671619       jo10 -0.651223
# 5                5  1542595217967   292677779671619       jo10 -0.727837
# 6                6  1542595217968   292677799623619       jo10 -0.727837
# 7                7  1542595217969   292677819591619       jo10 -0.378284
# 8                8  1542595217969   292677839543619       jo10 -0.325611
# 9                9  1542595218013   292677859511619       jo10 -0.359130
# 10              10  1542595218014   292677879495619       jo10 -0.196325
# 11              11  1542595218014   292677899463619       jo10 -0.397437
# 12              12  1542595218133   292677919415619       jo10 -0.205901
# 13              13  1542595218134   292677939383619       jo10 -0.445322
# 14              14  1542595218135   292677959335619       jo10 -0.038307
# 15              15  1542595218135   292677979335619       jo10 -0.172383
# 16              16  1542595218136   292677999287619       jo10 -0.325611
# 17              17  1542595218137   292678019255619       jo10 -0.162806
# 18              18  1542595218138   292678039207619       jo10 -0.057461
# 19              19  1542595218202   292678059175619       jo10 -0.158017
# 20              20  1542595218204   292678079159619       jo10 -0.215478
# 21              21  1542595218204   292678099127619       jo10 -0.057461
# 22              22  1542595218332   292678119079619       jo10 -0.033519
# 23              23  1542595218333   292678139047619       jo10  0.244209
# 24              24  1542595218334   292678158999619       jo10  0.301669
# 25              25  1542595218335   292678178999619       jo10  0.114922
# 26              26  1542595218337   292678198935619       jo10 -0.177171
# 27              27  1542595218338   292678218919619       jo10 -0.028730
# 28              28  1542595218339   292678238887619       jo10 -0.191536
# 29              29  1542595218402   292678258839619       jo10 -0.244209
# ...            ...            ...               ...        ...       ...
# 552936        3126  1541942076634  5916141136585153    Andres1 -0.770933
# 552937        3127  1541942076833  5916141336249153    Andres1 -0.919373
# 552938        3128  1541942077031  5916141535897153    Andres1 -0.909797
# 552939        3129  1541942077229  5916141735561153    Andres1 -0.852336
# 552940        3130  1541942077429  5916141935193153    Andres1 -0.852336
# 552941        3131  1541942077629  5916142134857153    Andres1 -0.924162
# 552942        3132  1541942077828  5916142334537153    Andres1 -0.890643
# 552943        3133  1541942078027  5916142534169153    Andres1 -1.019930
# 552944        3134  1541942078227  5916142733833153    Andres1 -0.924162
# 552945        3135  1541942078427  5916142933465153    Andres1 -1.072602
# 552946        3136  1541942078628  5916143133129153    Andres1 -1.110910
# 552947        3137  1541942078826  5916143332777153    Andres1 -1.082179
# 552948        3138  1541942079029  5916143532441153    Andres1 -1.091756
# 552949        3139  1541942079228  5916143732073153    Andres1 -1.010353
# 552950        3140  1541942079426  5916143931753153    Andres1 -0.981623
# 552951        3141  1541942079626  5916144131385153    Andres1 -0.828394
# 552952        3142  1541942079826  5916144331049153    Andres1 -0.909797
# 552953        3143  1541942080025  5916144530681153    Andres1 -1.000776
# 552954        3144  1541942080225  5916144730361153    Andres1 -1.029507
# 552955        3145  1541942080425  5916144929993153    Andres1 -0.876278
# 552956        3146  1541942080624  5916145129657153    Andres1 -0.948104
# 552957        3147  1541942080826  5916145329321153    Andres1 -0.895431
# 552958        3148  1541942081023  5916145528969153    Andres1 -0.885855
# 552959        3149  1541942081226  5916145728633153    Andres1 -0.943315
# 552960        3150  1541942081422  5916145928265153    Andres1 -0.881066
# 552961        3151  1541942081623  5916146127929153    Andres1 -0.900220
# 552962        3152  1541942081822  5916146327577153    Andres1 -0.852336
# 552963        3153  1541942082024  5916146527241153    Andres1 -0.866701
# 552964        3154  1541942082223  5916146726873153    Andres1 -0.972046
# 552965        3155  1541942082422  5916146926537153    Andres1 -1.225831
#
#                Y         Z  Phone_orientation
# 0       5.492299  8.374918                  0
# 1       5.272032  8.547300                  0
# 2       5.401319  8.245630                  0
# 3       5.329493  8.092401                  0
# 4       5.339070  8.317456                  0
# 5       5.535394  8.805874                  0
# 6       5.310340  8.614338                  0
# 7       5.281609  8.154651                  0
# 8       5.334281  8.188170                  0
# 9       5.358223  8.346188                  0
# 10      5.185841  8.283937                  0
# 11      5.171476  7.910442                  0
# 12      5.209783  8.025364                  0
# 13      5.248090  8.528147                  0
# 14      5.487510  8.245630                  0
# 15      5.190630  9.054871                  0
# 16      5.492299  8.604761                  0
# 17      5.185841  7.757214                  0
# 18      5.037400  7.594408                  0
# 19      5.300763  8.456321                  0
# 20      5.329493  8.676587                  0
# 21      5.085284  8.695741                  0
# 22      5.099649  8.547300                  0
# 23      5.391742  8.092401                  0
# 24      5.444415  8.063671                  0
# 25      5.487510  8.528147                  0
# 26      5.334281  9.059659                  0
# 27      5.722142  7.800309                  0
# 28      5.511452  8.681375                  0
# 29      5.473145  8.355764                  0
# ...          ...       ...                ...
# 552936  7.546524  6.536170                  0
# 552937  7.599196  6.464345                  0
# 552938  7.532158  6.215348                  0
# 552939  7.455544  6.354211                  0
# 552940  7.402872  6.263232                  0
# 552941  7.536947  6.119579                  0
# 552942  7.489063  6.172252                  0
# 552943  7.594408  6.306327                  0
# 552944  7.541735  6.277597                  0
# 552945  7.527370  6.622362                  0
# 552946  7.493851  6.789956                  0
# 552947  7.580042  6.751649                  0
# 552948  7.575254  6.976704                  0
# 552949  7.690176  6.359000                  0
# 552950  7.460332  6.507440                  0
# 552951  7.316680  6.502652                  0
# 552952  7.431602  6.469133                  0
# 552953  7.474698  6.421249                  0
# 552954  7.584831  6.421249                  0
# 552955  7.292738  6.483498                  0
# 552956  7.498640  6.339846                  0
# 552957  7.398083  6.402095                  0
# 552958  7.398083  6.569689                  0
# 552959  7.326257  6.732495                  0
# 552960  7.350199  6.612785                  0
# 552961  7.388506  6.435614                  0
# 552962  7.378930  6.426037                  0
# 552963  7.350199  6.464345                  0
# 552964  7.436390  6.306327                  0
# 552965  7.570466  6.440403                  0
#
# [552966 rows x 8 columns]
