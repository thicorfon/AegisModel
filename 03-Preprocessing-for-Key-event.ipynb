# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
file_name = 'KeyPressEvent'
df = pd.read_csv('../Our Data Windowed/' + file_name + '.csv')

# %%
df = df[df.WindowNumber != -1]

# %%
def get_deltas(df):
    deltas = []
    ultimo0 = 0
    ultimo1 = 0
    found0 = False
    found1 = False
    for _,row in df.iterrows():
        currentSystime = row.Systime
        if row.PressType == 0:
            if found1:
                deltas.append(currentSystime-ultimo1)
            else:
                deltas.append(None)
            ultimo0 = currentSystime
            found0 = True
        elif row.PressType == 1:
            if found0:
                deltas.append(currentSystime-ultimo0)
            else:
                deltas.append(None)
            ultimo1 = currentSystime
            found1 = True
    return deltas

# %%
aux = []
for session in df.SessionID.unique():
    aux += get_deltas(df[df.SessionID == session])
    print(session)
df['Deltas'] = aux
# Out:
# Jo1
# Diego01
# Toto1
# Toto6
# jo3
# jo2
# Diego02
# Diego03
# Toto5
# Toto2

# %%
df
# Out:
#              Systime  PressTime  PressType ActivityID  KeyID  \
# 0      1537190598209        NaN          0        Jo1     -1
# 1      1537190598267        NaN          1        Jo1     -1
# 2      1537190598667        NaN          0        Jo1    101
# 3      1537190598757        NaN          1        Jo1    101
# 4      1537190598822        NaN          0        Jo1    117
# 5      1537190598935        NaN          1        Jo1    117
# 6      1537190599224        NaN          0        Jo1     98
# 7      1537190599322        NaN          1        Jo1     98
# 8      1537190599545        NaN          0        Jo1    112
# 9      1537190599674        NaN          1        Jo1    112
# 10     1537190599712        NaN          0        Jo1    114
# 11     1537190599778        NaN          1        Jo1    114
# 12     1537190600083        NaN          0        Jo1    111
# 13     1537190600151        NaN          1        Jo1    111
# 14     1537190600887        NaN          0        Jo1     -5
# 15     1537190600897        NaN          1        Jo1     -5
# 16     1537190601043        NaN          0        Jo1     -5
# 17     1537190601052        NaN          1        Jo1     -5
# 18     1537190601192        NaN          0        Jo1     -5
# 19     1537190601201        NaN          1        Jo1     -5
# 20     1537190601337        NaN          0        Jo1     -5
# 21     1537190601346        NaN          1        Jo1     -5
# 22     1537190601503        NaN          0        Jo1     -5
# 23     1537190601512        NaN          1        Jo1     -5
# 24     1537190601939        NaN          0        Jo1     -1
# 25     1537190602018        NaN          1        Jo1     -1
# 26     1537190602377        NaN          0        Jo1    117
# 27     1537190602462        NaN          1        Jo1    117
# 28     1537190602830        NaN          0        Jo1     32
# 29     1537190602839        NaN          1        Jo1     32
# ...              ...        ...        ...        ...    ...
# 25304  1540743289502        NaN          0      Toto2    100
# 25305  1540743289514        NaN          1      Toto2    100
# 25306  1540743289639        NaN          0      Toto2     97
# 25307  1540743289713        NaN          1      Toto2     97
# 25308  1540743289830        NaN          0      Toto2    114
# 25309  1540743289871        NaN          1      Toto2    114
# 25310  1540743289920        NaN          0      Toto2    105
# 25311  1540743289928        NaN          1      Toto2    105
# 25312  1540743290011        NaN          0      Toto2     97
# 25313  1540743290104        NaN          1      Toto2     97
# 25314  1540743291330        NaN          0      Toto2     32
# 25315  1540743291334        NaN          1      Toto2     32
# 25316  1540743291568        NaN          0      Toto2    111
# 25317  1540743291624        NaN          1      Toto2    111
# 25318  1540743291808        NaN          0      Toto2     32
# 25319  1540743291812        NaN          1      Toto2     32
# 25320  1540743291891        NaN          0      Toto2     99
# 25321  1540743291952        NaN          1      Toto2     99
# 25322  1540743292095        NaN          0      Toto2    114
# 25323  1540743292174        NaN          1      Toto2    114
# 25324  1540743292195        NaN          0      Toto2    105
# 25325  1540743292237        NaN          1      Toto2    105
# 25326  1540743292354        NaN          0      Toto2    109
# 25327  1540743292413        NaN          1      Toto2    109
# 25328  1540743292449        NaN          0      Toto2    101
# 25329  1540743292548        NaN          1      Toto2    101
# 25330  1540743292745        NaN          0      Toto2     46
# 25331  1540743292810        NaN          1      Toto2     46
# 25332  1540743293133        NaN          0      Toto2     -3
# 25333  1540743293203        NaN          1      Toto2     -3
#
#        Phone_orientation SessionID  WindowNumber  Deltas
# 0                      0       Jo1           NaN     NaN
# 1                      0       Jo1           0.0    58.0
# 2                      0       Jo1           0.0   400.0
# 3                      0       Jo1           0.0    90.0
# 4                      0       Jo1           0.0    65.0
# 5                      0       Jo1           0.0   113.0
# 6                      0       Jo1           0.0   289.0
# 7                      0       Jo1           0.0    98.0
# 8                      0       Jo1           0.0   223.0
# 9                      0       Jo1           0.0   129.0
# 10                     0       Jo1           0.0    38.0
# 11                     0       Jo1           0.0    66.0
# 12                     0       Jo1           0.0   305.0
# 13                     0       Jo1           0.0    68.0
# 14                     0       Jo1           0.0   736.0
# 15                     0       Jo1           0.0    10.0
# 16                     0       Jo1           0.0   146.0
# 17                     0       Jo1           0.0     9.0
# 18                     0       Jo1           0.0   140.0
# 19                     0       Jo1           0.0     9.0
# 20                     0       Jo1           0.0   136.0
# 21                     0       Jo1           0.0     9.0
# 22                     0       Jo1           0.0   157.0
# 23                     0       Jo1           0.0     9.0
# 24                     0       Jo1           0.0   427.0
# 25                     0       Jo1           0.0    79.0
# 26                     0       Jo1           0.0   359.0
# 27                     0       Jo1           0.0    85.0
# 28                     0       Jo1           0.0   368.0
# 29                     0       Jo1           0.0     9.0
# ...                  ...       ...           ...     ...
# 25304                  0     Toto2          41.0    35.0
# 25305                  0     Toto2          41.0    12.0
# 25306                  0     Toto2          41.0   125.0
# 25307                  0     Toto2          41.0    74.0
# 25308                  0     Toto2          41.0   117.0
# 25309                  0     Toto2          41.0    41.0
# 25310                  0     Toto2          41.0    49.0
# 25311                  0     Toto2          41.0     8.0
# 25312                  0     Toto2          41.0    83.0
# 25313                  0     Toto2          41.0    93.0
# 25314                  0     Toto2           NaN  1226.0
# 25315                  0     Toto2           NaN     4.0
# 25316                  0     Toto2           NaN   234.0
# 25317                  0     Toto2           NaN    56.0
# 25318                  0     Toto2           NaN   184.0
# 25319                  0     Toto2           NaN     4.0
# 25320                  0     Toto2           NaN    79.0
# 25321                  0     Toto2           NaN    61.0
# 25322                  0     Toto2           NaN   143.0
# 25323                  0     Toto2           NaN    79.0
# 25324                  0     Toto2           NaN    21.0
# 25325                  0     Toto2           NaN    42.0
# 25326                  0     Toto2           NaN   117.0
# 25327                  0     Toto2           NaN    59.0
# 25328                  0     Toto2           NaN    36.0
# 25329                  0     Toto2           NaN    99.0
# 25330                  0     Toto2           NaN   197.0
# 25331                  0     Toto2           NaN    65.0
# 25332                  0     Toto2           NaN   323.0
# 25333                  0     Toto2           NaN    70.0
#
# [25334 rows x 9 columns]

# %%
def getPressTypeDelta(x):
    print(x == 1)

# %%
grouped_df = df.groupby(['SessionID', 'WindowNumber']).agg({
    'PressType': {
        'Press_count': lambda x: x.count(),
    }
})
# Out:
# /Users/thicorfon/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)

# %%
filteredByPressType1 = df[df.PressType == 1].copy()
filteredByPressType0 = df[df.PressType == 0].copy()

# %%
grouped0_df = filteredByPressType0.groupby(['SessionID', 'WindowNumber']).agg({
    'Deltas': {
        'Deltas_0_mean': 'mean',
        'Deltas_0_median': 'median',
        'Deltas_0_std': 'std'
    }
})
# Out:
# /Users/thicorfon/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)

# %%
grouped1_df = filteredByPressType1.groupby(['SessionID', 'WindowNumber']).agg({
    'Deltas': {
        'Deltas_1_mean': 'mean',
        'Deltas_1_median': 'median',
        'Deltas_1_std': 'std'
    }
})
# Out:
# /Users/thicorfon/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)

# %%
features = grouped_df.merge(grouped0_df, left_index=True, right_index=True).merge(grouped1_df, left_index=True, right_index=True)

# %%
features.columns = features.columns.droplevel()

# %%
features = features.reset_index()

# %%
features
# Out:
#     SessionID  WindowNumber  Press_count  Deltas_0_mean  Deltas_0_median  \
# 0     Diego01           0.0           15     573.714286            113.0
# 1     Diego01           1.0           42     198.523810            151.0
# 2     Diego01           2.0           18     493.666667            134.0
# 3     Diego01           3.0           51     130.846154             85.0
# 4     Diego01           4.0           51     128.760000            135.0
# 5     Diego01           5.0           19     447.400000            141.0
# 6     Diego01           6.0           43     177.952381            155.0
# 7     Diego01           7.0           40     186.900000            138.0
# 8     Diego01           8.0           32     229.937500            151.0
# 9     Diego01           9.0           46     147.000000            136.0
# 10    Diego01          10.0           12     878.333333            538.5
# 11    Diego01          11.0           44     160.772727            138.0
# 12    Diego01          12.0           40     191.350000            109.0
# 13    Diego01          13.0           10     142.200000             93.0
# 14    Diego01          14.0            6    2594.666667            871.0
# 15    Diego01          15.0           20     504.600000            121.5
# 16    Diego01          16.0           33     253.882353            146.0
# 17    Diego01          17.0           25     293.250000            157.5
# 18    Diego01          18.0           36     257.500000            163.0
# 19    Diego01          19.0           34     203.470588            140.0
# 20    Diego01          21.0           32     600.875000            142.5
# 21    Diego01          22.0           54     122.740741            114.0
# 22    Diego01          23.0           46     164.913043            122.0
# 23    Diego01          24.0           16     250.750000            172.5
# 24    Diego01          25.0           12    1101.333333             99.5
# 25    Diego01          26.0           36     238.833333            107.0
# 26    Diego01          27.0           34     314.833333            184.0
# 27    Diego01          28.0           52     129.692308            109.5
# 28    Diego01          29.0           38     189.210526            135.0
# 29    Diego01          30.0           40     232.650000            153.5
# ..        ...           ...          ...            ...              ...
# 612       jo3          50.0           41     148.100000            133.5
# 613       jo3          51.0           48     155.750000            116.5
# 614       jo3          52.0            6     181.666667             67.0
# 615       jo3          53.0           22     780.727273            236.0
# 616       jo3          54.0           48     133.250000            108.5
# 617       jo3          55.0           36     197.500000            172.5
# 618       jo3          56.0           35     229.333333            141.5
# 619       jo3          57.0           29     251.714286            186.0
# 620       jo3          58.0           20     495.700000            217.5
# 621       jo3          59.0           46     166.521739            135.0
# 622       jo3          60.0           47     135.833333            121.5
# 623       jo3          61.0           36     196.777778            153.0
# 624       jo3          62.0           45     154.909091            144.5
# 625       jo3          63.0           42     176.428571            151.0
# 626       jo3          64.0           58     112.862069             92.0
# 627       jo3          65.0           32     267.625000            139.0
# 628       jo3          66.0           36     192.388889            135.0
# 629       jo3          67.0           38     229.052632            146.0
# 630       jo3          68.0           53     108.259259             97.0
# 631       jo3          69.0           39     168.684211            108.0
# 632       jo3          70.0           42     200.666667            131.0
# 633       jo3          71.0           50     122.520000            116.0
