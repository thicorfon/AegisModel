# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
file_name = 'KeyPressEvent'
df = pd.read_csv('../Our Data Windowed/' + file_name + '.csv')

# %%
df = df[df.WindowNumber != -1]

# %%
def get_deltas(df):
    deltas = []
    ultimo0 = 0
    ultimo1 = 0
    found0 = False
    found1 = False
    for _,row in df.iterrows():
        currentSystime = row.Systime
        if row.PressType == 0:
            if found1:
                deltas.append(currentSystime-ultimo1)
            else:
                deltas.append(None)
            ultimo0 = currentSystime
            found0 = True
        elif row.PressType == 1:
            if found0:
                deltas.append(currentSystime-ultimo0)
            else:
                deltas.append(None)
            ultimo1 = currentSystime
            found1 = True
    return deltas

# %%
aux = []
for session in df.SessionID.unique():
    aux += get_deltas(df[df.SessionID == session])
    print(session)
df['Deltas'] = aux
# Out:
# jo9
# jo7
# oscar1
# Jo1
# jo6
# jo8
# Diego01
# Diego06
# Toto10
# Diego07
# Toto8
# Toto1
# Toto6
# Toto7
# Toto9
# jo3
# jo4
# jo5
# jo2
# Diego05
# Diego02
# Pedro1
# Diego03
# Diego04
# Carlos1
# Toto5
# Toto2
# Andres1

# %%
df
# Out:
#              Systime  PressTime  PressType ActivityID  KeyID  \
# 0      1542583365550        NaN          0        jo9     -1
# 1      1542583365628        NaN          1        jo9     -1
# 2      1542583366521        NaN          0        jo9    101
# 3      1542583366622        NaN          1        jo9    101
# 4      1542583366660        NaN          0        jo9    117
# 5      1542583366727        NaN          1        jo9    117
# 6      1542583366992        NaN          0        jo9     32
# 7      1542583367002        NaN          1        jo9     32
# 8      1542583367398        NaN          0        jo9     99
# 9      1542583367481        NaN          1        jo9     99
# 10     1542583367491        NaN          0        jo9    111
# 11     1542583367599        NaN          1        jo9    111
# 12     1542583367751        NaN          0        jo9    109
# 13     1542583367860        NaN          1        jo9    109
# 14     1542583368752        NaN          0        jo9     -5
# 15     1542583368762        NaN          1        jo9     -5
# 16     1542583369738        NaN          0        jo9    109
# 17     1542583369827        NaN          1        jo9    109
# 18     1542583370020        NaN          0        jo9     32
# 19     1542583370032        NaN          1        jo9     32
# 20     1542583370485        NaN          0        jo9     99
# 21     1542583370575        NaN          1        jo9     99
# 22     1542583370787        NaN          0        jo9    101
# 23     1542583370900        NaN          1        jo9    101
# 24     1542583371045        NaN          0        jo9    114
# 25     1542583371153        NaN          1        jo9    114
# 26     1542583371540        NaN          0        jo9    116
# 27     1542583371639        NaN          1        jo9    116
# 28     1542583371915        NaN          0        jo9    101
# 29     1542583371993        NaN          1        jo9    101
# ...              ...        ...        ...        ...    ...
# 80144  1541942061772        NaN          0    Andres1     46
# 80145  1541942061868        NaN          1    Andres1     46
# 80146  1541942062094        NaN          0    Andres1     32
# 80147  1541942062100        NaN          1    Andres1     32
# 80148  1541942064096        NaN          0    Andres1     -1
# 80149  1541942064182        NaN          1    Andres1     -1
# 80150  1541942064595        NaN          0    Andres1     97
# 80151  1541942064670        NaN          1    Andres1     97
# 80152  1541942064850        NaN          0    Andres1    113
# 80153  1541942064931        NaN          1    Andres1    113
# 80154  1541942065354        NaN          0    Andres1    117
# 80155  1541942065434        NaN          1    Andres1    117
# 80156  1541942066508        NaN          0    Andres1     -5
# 80157  1541942066513        NaN          1    Andres1     -5
# 80158  1541942066781        NaN          0    Andres1     -5
# 80159  1541942066787        NaN          1    Andres1     -5
# 80160  1541942068610        NaN          0    Andres1     -1
# 80161  1541942068693        NaN          1    Andres1     -1
# 80162  1541942069442        NaN          0    Andres1    113
# 80163  1541942069514        NaN          1    Andres1    113
# 80164  1541942070045        NaN          0    Andres1    117
# 80165  1541942070119        NaN          1    Andres1    117
# 80166  1541942070259        NaN          0    Andres1    105
# 80167  1541942070357        NaN          1    Andres1    105
# 80168  1541942070996        NaN          0    Andres1     32
# 80169  1541942071003        NaN          1    Andres1     32
# 80170  1541942071415        NaN          0    Andres1    110
# 80171  1541942071499        NaN          1    Andres1    110
# 80172  1541942071728        NaN          0    Andres1    111
# 80173  1541942071831        NaN          1    Andres1    111
#
#        Phone_orientation SessionID  WindowNumber  Deltas
# 0                      0       jo9             0     NaN
# 1                      0       jo9             0    78.0
# 2                      0       jo9             0   893.0
# 3                      0       jo9             0   101.0
# 4                      0       jo9             0    38.0
# 5                      0       jo9             0    67.0
# 6                      0       jo9             0   265.0
# 7                      0       jo9             0    10.0
# 8                      0       jo9             0   396.0
# 9                      0       jo9             0    83.0
# 10                     0       jo9             0    10.0
# 11                     0       jo9             0   108.0
# 12                     0       jo9             0   152.0
# 13                     0       jo9             0   109.0
# 14                     0       jo9             0   892.0
# 15                     0       jo9             0    10.0
# 16                     0       jo9             0   976.0
# 17                     0       jo9             0    89.0
# 18                     0       jo9             0   193.0
# 19                     0       jo9             0    12.0
# 20                     0       jo9             0   453.0
# 21                     0       jo9             0    90.0
# 22                     0       jo9             0   212.0
# 23                     0       jo9             0   113.0
# 24                     0       jo9             0   145.0
# 25                     0       jo9             0   108.0
# 26                     0       jo9             0   387.0
# 27                     0       jo9             0    99.0
# 28                     0       jo9             0   276.0
# 29                     0       jo9             0    78.0
# ...                  ...       ...           ...     ...
# 80144                  0   Andres1            53   902.0
# 80145                  0   Andres1            53    96.0
# 80146                  0   Andres1            53   226.0
# 80147                  0   Andres1            53     6.0
# 80148                  0   Andres1            53  1996.0
# 80149                  0   Andres1            53    86.0
# 80150                  0   Andres1            53   413.0
# 80151                  0   Andres1            53    75.0
# 80152                  0   Andres1            53   180.0
# 80153                  0   Andres1            54    81.0
# 80154                  0   Andres1            54   423.0
# 80155                  0   Andres1            54    80.0
# 80156                  0   Andres1            54  1074.0
# 80157                  0   Andres1            54     5.0
# 80158                  0   Andres1            54   268.0
# 80159                  0   Andres1            54     6.0
# 80160                  0   Andres1            54  1823.0
# 80161                  0   Andres1            54    83.0
# 80162                  0   Andres1            54   749.0
# 80163                  0   Andres1            54    72.0
# 80164                  0   Andres1            54   531.0
# 80165                  0   Andres1            54    74.0
# 80166                  0   Andres1            54   140.0
# 80167                  0   Andres1            54    98.0
# 80168                  0   Andres1            54   639.0
# 80169                  0   Andres1            54     7.0
# 80170                  0   Andres1            54   412.0
# 80171                  0   Andres1            54    84.0
# 80172                  0   Andres1            54   229.0
# 80173                  0   Andres1            54   103.0
#
# [79298 rows x 9 columns]

# %%
def getPressTypeDelta(x):
    print(x == 1)

# %%
grouped_df = df.groupby(['SessionID', 'WindowNumber']).agg({
    'PressType': {
        'Press_count': lambda x: x.count(),
    }
})
# Out:
# /Users/thicorfon/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)

# %%
filteredByPressType1 = df[df.PressType == 1].copy()
filteredByPressType0 = df[df.PressType == 0].copy()

# %%
grouped0_df = filteredByPressType0.groupby(['SessionID', 'WindowNumber']).agg({
    'Deltas': {
        'Deltas_0_mean': 'mean',
        'Deltas_0_median': 'median',
        'Deltas_0_std': 'std'
    }
})
# Out:
# /Users/thicorfon/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)

# %%
grouped1_df = filteredByPressType1.groupby(['SessionID', 'WindowNumber']).agg({
    'Deltas': {
        'Deltas_1_mean': 'mean',
        'Deltas_1_median': 'median',
        'Deltas_1_std': 'std'
    }
})
# Out:
# /Users/thicorfon/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)

# %%
features = grouped_df.merge(grouped0_df, left_index=True, right_index=True).merge(grouped1_df, left_index=True, right_index=True)

# %%
features.columns = features.columns.droplevel()

# %%
features = features.reset_index()

# %%
features
# Out:
#      SessionID  WindowNumber  Press_count  Deltas_0_mean  Deltas_0_median  \
# 0      Andres1             0            6     585.000000            585.0
# 1      Andres1             1           16    2251.000000            722.0
# 2      Andres1             2           26     639.076923            539.0
# 3      Andres1             3            7    2486.000000            465.5
# 4      Andres1             4           38     462.631579            334.0
# 5      Andres1             5           37     478.777778            396.0
# 6      Andres1             6           28     624.142857            597.0
# 7      Andres1             7           32     598.812500            426.0
# 8      Andres1             8           30     406.733333            418.0
# 9      Andres1            12            6   14257.666667            943.0
# 10     Andres1            13           22     821.272727            467.0
# 11     Andres1            14           42     423.095238            339.0
# 12     Andres1            15           28     652.214286            457.5
# 13     Andres1            16           18     549.666667            203.0
# 14     Andres1            19           12    5604.333333            507.5
# 15     Andres1            20           32     634.625000            474.5
# 16     Andres1            21           22     705.636364            442.0
# 17     Andres1            25           28    2939.642857            419.5
# 18     Andres1            26           14     753.857143            790.0
# 19     Andres1            27           18    1471.888889            398.0
# 20     Andres1            28           32     581.750000            424.0
# 21     Andres1            29           30     577.400000            434.0
# 22     Andres1            30           12    1648.333333           1543.0
# 23     Andres1            31           24     779.333333            464.0
# 24     Andres1            33           20    1697.700000            317.0
# 25     Andres1            34           52     416.346154            218.5
# 26     Andres1            35           32     573.750000            405.0
# 27     Andres1            36           18     783.666667            300.0
# 28     Andres1            37           22     874.454545            527.0
# 29     Andres1            39           22    1982.181818            385.0
# ...        ...           ...          ...            ...              ...
# 1033       jo9            34           86     163.837209            119.0
# 1034       jo9            35           64     255.437500            137.0
# 1035       jo9            36           84     174.238095            141.5
# 1036       jo9            37           78     199.307692            138.0
# 1037       jo9            38           81     177.829268            127.0
# 1038       jo9            39          103     126.576923            101.0
# 1039       jo9            40           82     184.829268            127.0
# 1040       jo9            41           88     151.272727            121.0
# 1041       jo9            42           76     200.342105            111.5
# 1042       jo9            43           99     140.080000            138.5
# 1043       jo9            44           88     157.977273            119.5
# 1044       jo9            45           86     148.348837            108.0
# 1045       jo9            46           88     182.022727            138.5
# 1046       jo9            47           84     178.047619            135.5
# 1047       jo9            48           86     162.232558            137.0
# 1048       jo9            49           94     146.425532            125.0
# 1049    oscar1             0           51     345.640000            123.0
# 1050    oscar1             1           41     650.818182            190.0
# 1051    oscar1             2           34     503.705882            182.0
# 1052    oscar1             3           42     289.714286            203.0
# 1053    oscar1             4           68     353.823529            133.5
# 1054    oscar1             5           36     430.055556            289.0
# 1055    oscar1             6           76     183.842105            148.0
# 1056    oscar1             7           30     532.533333            145.0
# 1057    oscar1             9           14    1952.285714            313.0
