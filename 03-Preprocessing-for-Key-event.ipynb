# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
file_name = 'KeyPressEvent'
df = pd.read_csv('../Our Data Windowed/' + file_name + '.csv')

# %%
df = df[df.WindowNumber != -1]

# %%
def get_deltas(df):
    deltas = []
    ultimo0 = 0
    ultimo1 = 0
    found0 = False
    found1 = False
    for _,row in df.iterrows():
        currentSystime = row.Systime
        if row.PressType == 0:
            if found1:
                deltas.append(currentSystime-ultimo1)
            else:
                deltas.append(None)
            ultimo0 = currentSystime
            found0 = True
        elif row.PressType == 1:
            if found0:
                deltas.append(currentSystime-ultimo0)
            else:
                deltas.append(None)
            ultimo1 = currentSystime
            found1 = True
    return deltas

# %%
aux = []
for session in df.SessionID.unique():
    aux += get_deltas(df[df.SessionID == session])
    print(session)
df['Deltas'] = aux
# Out:
# Jo1
# Diego01
# Toto10
# Toto8
# Toto1
# Toto6
# Toto7
# Toto9
# jo3
# jo4
# jo5
# jo2
# Diego05
# Diego02
# Diego03
# Diego04
# Toto5
# Toto2
# Andres1

# %%
df
# Out:
#              Systime  PressTime  PressType ActivityID  KeyID  \
# 0      1537190598209        NaN          0        Jo1     -1
# 1      1537190598267        NaN          1        Jo1     -1
# 2      1537190598667        NaN          0        Jo1    101
# 3      1537190598757        NaN          1        Jo1    101
# 4      1537190598822        NaN          0        Jo1    117
# 5      1537190598935        NaN          1        Jo1    117
# 6      1537190599224        NaN          0        Jo1     98
# 7      1537190599322        NaN          1        Jo1     98
# 8      1537190599545        NaN          0        Jo1    112
# 9      1537190599674        NaN          1        Jo1    112
# 10     1537190599712        NaN          0        Jo1    114
# 11     1537190599778        NaN          1        Jo1    114
# 12     1537190600083        NaN          0        Jo1    111
# 13     1537190600151        NaN          1        Jo1    111
# 14     1537190600887        NaN          0        Jo1     -5
# 15     1537190600897        NaN          1        Jo1     -5
# 16     1537190601043        NaN          0        Jo1     -5
# 17     1537190601052        NaN          1        Jo1     -5
# 18     1537190601192        NaN          0        Jo1     -5
# 19     1537190601201        NaN          1        Jo1     -5
# 20     1537190601337        NaN          0        Jo1     -5
# 21     1537190601346        NaN          1        Jo1     -5
# 22     1537190601503        NaN          0        Jo1     -5
# 23     1537190601512        NaN          1        Jo1     -5
# 24     1537190601939        NaN          0        Jo1     -1
# 25     1537190602018        NaN          1        Jo1     -1
# 26     1537190602377        NaN          0        Jo1    117
# 27     1537190602462        NaN          1        Jo1    117
# 28     1537190602830        NaN          0        Jo1     32
# 29     1537190602839        NaN          1        Jo1     32
# ...              ...        ...        ...        ...    ...
# 52622  1541942061772        NaN          0    Andres1     46
# 52623  1541942061868        NaN          1    Andres1     46
# 52624  1541942062094        NaN          0    Andres1     32
# 52625  1541942062100        NaN          1    Andres1     32
# 52626  1541942064096        NaN          0    Andres1     -1
# 52627  1541942064182        NaN          1    Andres1     -1
# 52628  1541942064595        NaN          0    Andres1     97
# 52629  1541942064670        NaN          1    Andres1     97
# 52630  1541942064850        NaN          0    Andres1    113
# 52631  1541942064931        NaN          1    Andres1    113
# 52632  1541942065354        NaN          0    Andres1    117
# 52633  1541942065434        NaN          1    Andres1    117
# 52634  1541942066508        NaN          0    Andres1     -5
# 52635  1541942066513        NaN          1    Andres1     -5
# 52636  1541942066781        NaN          0    Andres1     -5
# 52637  1541942066787        NaN          1    Andres1     -5
# 52638  1541942068610        NaN          0    Andres1     -1
# 52639  1541942068693        NaN          1    Andres1     -1
# 52640  1541942069442        NaN          0    Andres1    113
# 52641  1541942069514        NaN          1    Andres1    113
# 52642  1541942070045        NaN          0    Andres1    117
# 52643  1541942070119        NaN          1    Andres1    117
# 52644  1541942070259        NaN          0    Andres1    105
# 52645  1541942070357        NaN          1    Andres1    105
# 52646  1541942070996        NaN          0    Andres1     32
# 52647  1541942071003        NaN          1    Andres1     32
# 52648  1541942071415        NaN          0    Andres1    110
# 52649  1541942071499        NaN          1    Andres1    110
# 52650  1541942071728        NaN          0    Andres1    111
# 52651  1541942071831        NaN          1    Andres1    111
#
#        Phone_orientation SessionID  WindowNumber  Deltas
# 0                      0       Jo1             0     NaN
# 1                      0       Jo1             0    58.0
# 2                      0       Jo1             0   400.0
# 3                      0       Jo1             0    90.0
# 4                      0       Jo1             0    65.0
# 5                      0       Jo1             0   113.0
# 6                      0       Jo1             0   289.0
# 7                      0       Jo1             0    98.0
# 8                      0       Jo1             0   223.0
# 9                      0       Jo1             0   129.0
# 10                     0       Jo1             0    38.0
# 11                     0       Jo1             0    66.0
# 12                     0       Jo1             0   305.0
# 13                     0       Jo1             0    68.0
# 14                     0       Jo1             0   736.0
# 15                     0       Jo1             0    10.0
# 16                     0       Jo1             0   146.0
# 17                     0       Jo1             0     9.0
# 18                     0       Jo1             0   140.0
# 19                     0       Jo1             0     9.0
# 20                     0       Jo1             0   136.0
# 21                     0       Jo1             0     9.0
# 22                     0       Jo1             0   157.0
# 23                     0       Jo1             0     9.0
# 24                     0       Jo1             0   427.0
# 25                     0       Jo1             0    79.0
# 26                     0       Jo1             0   359.0
# 27                     0       Jo1             0    85.0
# 28                     0       Jo1             0   368.0
# 29                     0       Jo1             0     9.0
# ...                  ...       ...           ...     ...
# 52622                  0   Andres1            53   902.0
# 52623                  0   Andres1            53    96.0
# 52624                  0   Andres1            53   226.0
# 52625                  0   Andres1            53     6.0
# 52626                  0   Andres1            53  1996.0
# 52627                  0   Andres1            53    86.0
# 52628                  0   Andres1            53   413.0
# 52629                  0   Andres1            53    75.0
# 52630                  0   Andres1            53   180.0
# 52631                  0   Andres1            54    81.0
# 52632                  0   Andres1            54   423.0
# 52633                  0   Andres1            54    80.0
# 52634                  0   Andres1            54  1074.0
# 52635                  0   Andres1            54     5.0
# 52636                  0   Andres1            54   268.0
# 52637                  0   Andres1            54     6.0
# 52638                  0   Andres1            54  1823.0
# 52639                  0   Andres1            54    83.0
# 52640                  0   Andres1            54   749.0
# 52641                  0   Andres1            54    72.0
# 52642                  0   Andres1            54   531.0
# 52643                  0   Andres1            54    74.0
# 52644                  0   Andres1            54   140.0
# 52645                  0   Andres1            54    98.0
# 52646                  0   Andres1            54   639.0
# 52647                  0   Andres1            54     7.0
# 52648                  0   Andres1            54   412.0
# 52649                  0   Andres1            54    84.0
# 52650                  0   Andres1            54   229.0
# 52651                  0   Andres1            54   103.0
#
# [51897 rows x 9 columns]

# %%
def getPressTypeDelta(x):
    print(x == 1)

# %%
grouped_df = df.groupby(['SessionID', 'WindowNumber']).agg({
    'PressType': {
        'Press_count': lambda x: x.count(),
    }
})
# Out:
# /Users/thicorfon/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)

# %%
filteredByPressType1 = df[df.PressType == 1].copy()
filteredByPressType0 = df[df.PressType == 0].copy()

# %%
grouped0_df = filteredByPressType0.groupby(['SessionID', 'WindowNumber']).agg({
    'Deltas': {
        'Deltas_0_mean': 'mean',
        'Deltas_0_median': 'median',
        'Deltas_0_std': 'std'
    }
})
# Out:
# /Users/thicorfon/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)

# %%
grouped1_df = filteredByPressType1.groupby(['SessionID', 'WindowNumber']).agg({
    'Deltas': {
        'Deltas_1_mean': 'mean',
        'Deltas_1_median': 'median',
        'Deltas_1_std': 'std'
    }
})
# Out:
# /Users/thicorfon/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)

# %%
features = grouped_df.merge(grouped0_df, left_index=True, right_index=True).merge(grouped1_df, left_index=True, right_index=True)

# %%
features.columns = features.columns.droplevel()

# %%
features = features.reset_index()

# %%
features
# Out:
#     SessionID  WindowNumber  Press_count  Deltas_0_mean  Deltas_0_median  \
# 0     Andres1             0            6     585.000000            585.0
# 1     Andres1             1           16    2251.000000            722.0
# 2     Andres1             2           26     639.076923            539.0
# 3     Andres1             3            7    2486.000000            465.5
# 4     Andres1             4           38     462.631579            334.0
# 5     Andres1             5           37     478.777778            396.0
# 6     Andres1             6           28     624.142857            597.0
# 7     Andres1             7           32     598.812500            426.0
# 8     Andres1             8           30     406.733333            418.0
# 9     Andres1            12            6   14257.666667            943.0
# 10    Andres1            13           22     821.272727            467.0
# 11    Andres1            14           42     423.095238            339.0
# 12    Andres1            15           28     652.214286            457.5
# 13    Andres1            16           18     549.666667            203.0
# 14    Andres1            19           12    5604.333333            507.5
# 15    Andres1            20           32     634.625000            474.5
# 16    Andres1            21           22     705.636364            442.0
# 17    Andres1            25           28    2939.642857            419.5
# 18    Andres1            26           14     753.857143            790.0
# 19    Andres1            27           18    1471.888889            398.0
# 20    Andres1            28           32     581.750000            424.0
# 21    Andres1            29           30     577.400000            434.0
# 22    Andres1            30           12    1648.333333           1543.0
# 23    Andres1            31           24     779.333333            464.0
# 24    Andres1            33           20    1697.700000            317.0
# 25    Andres1            34           52     416.346154            218.5
# 26    Andres1            35           32     573.750000            405.0
# 27    Andres1            36           18     783.666667            300.0
# 28    Andres1            37           22     874.454545            527.0
# 29    Andres1            39           22    1982.181818            385.0
# ..        ...           ...          ...            ...              ...
# 649       jo5            18           81     179.829268            134.0
# 650       jo5            19           91     153.088889            117.0
# 651       jo5            20           98     138.979592            115.0
# 652       jo5            21           63     263.968750            167.0
# 653       jo5            22           71     209.257143            148.0
# 654       jo5            23           70     144.428571             99.0
# 655       jo5            24           72     518.555556            258.0
# 656       jo5            25           94     135.361702            108.0
# 657       jo5            26           90     154.088889            115.0
# 658       jo5            27           88     162.840909            136.0
# 659       jo5            28          100     119.980000             96.0
# 660       jo5            29           86     172.023256            126.0
# 661       jo5            30           54     166.148148            129.0
# 662       jo5            31           83     264.761905            140.5
# 663       jo5            32           76     201.631579            142.5
# 664       jo5            33           70     226.342857            144.0
# 665       jo5            34           76     192.210526            142.5
# 666       jo5            35           97     140.877551            137.0
# 667       jo5            36           91     152.066667            118.0
# 668       jo5            37           85     142.581395            114.0
# 669       jo5            38           75     184.810811            135.0
# 670       jo5            39           86     157.976744            117.0
# 671       jo5            40           62     260.806452            141.0
# 672       jo5            41           89     164.911111            116.0
# 673       jo5            42           87     164.581395            116.0
# 674       jo5            43           89     170.688889            140.0
# 675       jo5            44          100     118.460000            108.5
# 676       jo5            45           88     161.113636            135.0
# 677       jo5            46           82     178.024390            126.0
# 678       jo5            47           86     172.210526            134.0
#
#      Deltas_0_std  Deltas_1_mean  Deltas_1_median  Deltas_1_std
# 0       65.053824      68.666667             68.0      8.020806
# 1     4283.073429      66.000000             70.0     28.480570
# 2      439.608246     122.153846             87.0    191.819727
# 3     4206.432614      59.000000             82.0     43.347434
# 4      398.472669      66.736842             76.0     26.339329
# 5      256.692894      68.894737             82.0     33.125845
# 6      447.708500      51.785714             67.0     30.143703
# 7      345.488682      64.875000             69.0     36.877952
# 8      197.948935      61.400000             66.0     25.762098
# 9    23502.121231      62.000000             63.0     10.535654
# 10     709.976632      60.454545             64.0     32.309019
# 11     250.763814      62.619048             75.0     34.937768
# 12     543.551311      53.000000             72.0     37.849906
# 13     602.912514      19.333333              6.0     27.581697
# 14   12532.134769      59.166667             61.5     27.859768
# 15     444.386150      35.625000             28.5     32.109967
# 16     865.157011      72.272727             78.0     40.939201
# 17    9199.885155      48.928571             69.0     39.713327
# 18     301.935108      66.714286             74.0     30.928489
# 19    3212.027998      66.111111             65.0     26.107683
# 20     428.066739      65.250000             70.0     25.823762
# 21     336.887179      66.933333             67.0     25.641670
# 22    1292.135235      56.833333             70.0     41.791945
# 23     661.978211      62.833333             71.5     31.103444
# 24    3271.134395      64.200000             64.5      9.852242
# 25     511.843565      37.538462              6.0     38.957650
# 26     496.736080      66.812500             73.0     34.170589
# 27     857.252880      39.111111              6.0     40.513715
# 28     935.210496      66.818182             80.0     42.385890
# 29    5186.397609      67.818182             73.0     34.876405
# ..            ...            ...              ...           ...
# 649    162.133263      67.025000             79.0     36.929238
# 650    168.383197      59.673913             75.0     42.208506
# 651    111.952276      68.306122             84.0     38.531483
# 652    301.624257      57.000000             72.0     59.042358
# 653    296.312469      71.472222             86.0     36.446819
# 654    163.642236      74.657143             79.0     48.073438
# 655    938.220043     964.648148            906.0    829.692195
# 656    107.972707      77.255319             90.0     36.688150
# 657    202.944778      68.488889             84.0     37.744730
# 658    123.167676      63.022727             84.0     46.626417
# 659     95.633333      73.240000             84.0     38.628297
# 660    146.185383      66.837209             76.0     41.592084
# 661    194.791941      83.407407             92.0     32.865997
# 662    678.678012      55.365854             65.0     40.347711
# 663    188.348932      64.789474             74.5     52.161474
# 664    234.252747      66.228571             80.0     37.789732
# 665    166.133479      69.763158             84.5     39.305068
# 666     95.446895      64.375000             80.0     42.481348
# 667    134.669697      67.847826             80.5     38.375899
# 668    131.384429      93.714286             74.5    154.573415
# 669    157.615361      78.052632             86.5     37.134487
# 670    153.060444      75.348837             84.0     35.797635
# 671    358.031416      61.129032             74.0     39.699489
# 672    164.600732      63.090909             74.0     43.485800
# 673    174.383162      64.386364             82.5     40.943646
# 674    143.194849      54.795455             72.5     41.368778
# 675     87.632398      81.620000             89.5     35.816363
# 676    181.757853      66.863636             82.5     40.304418
# 677    315.837418      65.243902             84.0     41.894976
# 678    155.862579     175.458333             84.5    243.891758
#
# [679 rows x 9 columns]

# %%
features.to_csv('../Our Data Features/'+file_name+ '_mean_std.csv', index=False)
