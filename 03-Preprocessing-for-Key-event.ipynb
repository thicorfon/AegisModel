# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
file_name = 'KeyPressEvent'
df = pd.read_csv('../Our Data Windowed/' + file_name + '.csv')

# %%
df = df[df.WindowNumber != -1]

# %%
def get_deltas(df):
    deltas = []
    ultimo0 = 0
    ultimo1 = 0
    found0 = False
    found1 = False
    for _,row in df.iterrows():
        currentSystime = row.Systime
        if row.PressType == 0:
            if found1:
                deltas.append(currentSystime-ultimo1)
            else:
                deltas.append(None)
            ultimo0 = currentSystime
            found0 = True
        elif row.PressType == 1:
            if found0:
                deltas.append(currentSystime-ultimo0)
            else:
                deltas.append(None)
            ultimo1 = currentSystime
            found1 = True
    return deltas

# %%
aux = []
for session in df.SessionID.unique():
    aux += get_deltas(df[df.SessionID == session])
    print(session)
df['Deltas'] = aux
# Out:
# Jo1
# Diego01
# Toto8
# Toto1
# Toto6
# Toto7
# Toto9
# jo3
# jo4
# jo2
# Diego02
# Diego03
# Diego04
# Toto5
# Toto2
# Andres1

# %%
df
# Out:
#              Systime  PressTime  PressType ActivityID  KeyID  \
# 0      1537190598209        NaN          0        Jo1     -1
# 1      1537190598267        NaN          1        Jo1     -1
# 2      1537190598667        NaN          0        Jo1    101
# 3      1537190598757        NaN          1        Jo1    101
# 4      1537190598822        NaN          0        Jo1    117
# 5      1537190598935        NaN          1        Jo1    117
# 6      1537190599224        NaN          0        Jo1     98
# 7      1537190599322        NaN          1        Jo1     98
# 8      1537190599545        NaN          0        Jo1    112
# 9      1537190599674        NaN          1        Jo1    112
# 10     1537190599712        NaN          0        Jo1    114
# 11     1537190599778        NaN          1        Jo1    114
# 12     1537190600083        NaN          0        Jo1    111
# 13     1537190600151        NaN          1        Jo1    111
# 14     1537190600887        NaN          0        Jo1     -5
# 15     1537190600897        NaN          1        Jo1     -5
# 16     1537190601043        NaN          0        Jo1     -5
# 17     1537190601052        NaN          1        Jo1     -5
# 18     1537190601192        NaN          0        Jo1     -5
# 19     1537190601201        NaN          1        Jo1     -5
# 20     1537190601337        NaN          0        Jo1     -5
# 21     1537190601346        NaN          1        Jo1     -5
# 22     1537190601503        NaN          0        Jo1     -5
# 23     1537190601512        NaN          1        Jo1     -5
# 24     1537190601939        NaN          0        Jo1     -1
# 25     1537190602018        NaN          1        Jo1     -1
# 26     1537190602377        NaN          0        Jo1    117
# 27     1537190602462        NaN          1        Jo1    117
# 28     1537190602830        NaN          0        Jo1     32
# 29     1537190602839        NaN          1        Jo1     32
# ...              ...        ...        ...        ...    ...
# 41573  1541942069442        NaN          0    Andres1    113
# 41574  1541942069514        NaN          1    Andres1    113
# 41575  1541942070045        NaN          0    Andres1    117
# 41576  1541942070119        NaN          1    Andres1    117
# 41577  1541942070259        NaN          0    Andres1    105
# 41578  1541942070357        NaN          1    Andres1    105
# 41579  1541942070996        NaN          0    Andres1     32
# 41580  1541942071003        NaN          1    Andres1     32
# 41581  1541942071415        NaN          0    Andres1    110
# 41582  1541942071499        NaN          1    Andres1    110
# 41583  1541942071728        NaN          0    Andres1    111
# 41584  1541942071831        NaN          1    Andres1    111
# 41585  1541942077477        NaN          0    Andres1     -5
# 41586  1541942077482        NaN          1    Andres1     -5
# 41587  1541942077710        NaN          0    Andres1     -5
# 41588  1541942077715        NaN          1    Andres1     -5
# 41589  1541942077906        NaN          0    Andres1     -5
# 41590  1541942077910        NaN          1    Andres1     -5
# 41591  1541942078121        NaN          0    Andres1     -5
# 41592  1541942078127        NaN          1    Andres1     -5
# 41593  1541942078320        NaN          0    Andres1     -5
# 41594  1541942078326        NaN          1    Andres1     -5
# 41595  1541942078541        NaN          0    Andres1     -5
# 41596  1541942078546        NaN          1    Andres1     -5
# 41597  1541942078756        NaN          0    Andres1     -5
# 41598  1541942078761        NaN          1    Andres1     -5
# 41599  1541942079005        NaN          0    Andres1     -5
# 41600  1541942079010        NaN          1    Andres1     -5
# 41601  1541942080965        NaN          0    Andres1     -3
# 41602  1541942081037        NaN          1    Andres1     -3
#
#        Phone_orientation SessionID  WindowNumber  Deltas
# 0                      0       Jo1           NaN     NaN
# 1                      0       Jo1           0.0    58.0
# 2                      0       Jo1           0.0   400.0
# 3                      0       Jo1           0.0    90.0
# 4                      0       Jo1           0.0    65.0
# 5                      0       Jo1           0.0   113.0
# 6                      0       Jo1           0.0   289.0
# 7                      0       Jo1           0.0    98.0
# 8                      0       Jo1           0.0   223.0
# 9                      0       Jo1           0.0   129.0
# 10                     0       Jo1           0.0    38.0
# 11                     0       Jo1           0.0    66.0
# 12                     0       Jo1           0.0   305.0
# 13                     0       Jo1           0.0    68.0
# 14                     0       Jo1           0.0   736.0
# 15                     0       Jo1           0.0    10.0
# 16                     0       Jo1           0.0   146.0
# 17                     0       Jo1           0.0     9.0
# 18                     0       Jo1           0.0   140.0
# 19                     0       Jo1           0.0     9.0
# 20                     0       Jo1           0.0   136.0
# 21                     0       Jo1           0.0     9.0
# 22                     0       Jo1           0.0   157.0
# 23                     0       Jo1           0.0     9.0
# 24                     0       Jo1           0.0   427.0
# 25                     0       Jo1           0.0    79.0
# 26                     0       Jo1           0.0   359.0
# 27                     0       Jo1           0.0    85.0
# 28                     0       Jo1           0.0   368.0
# 29                     0       Jo1           0.0     9.0
# ...                  ...       ...           ...     ...
# 41573                  0   Andres1          54.0   749.0
# 41574                  0   Andres1          54.0    72.0
# 41575                  0   Andres1          54.0   531.0
# 41576                  0   Andres1          54.0    74.0
# 41577                  0   Andres1          54.0   140.0
# 41578                  0   Andres1          54.0    98.0
# 41579                  0   Andres1          54.0   639.0
# 41580                  0   Andres1          54.0     7.0
# 41581                  0   Andres1          54.0   412.0
# 41582                  0   Andres1          54.0    84.0
# 41583                  0   Andres1          54.0   229.0
# 41584                  0   Andres1          54.0   103.0
# 41585                  0   Andres1           NaN  5646.0
# 41586                  0   Andres1           NaN     5.0
# 41587                  0   Andres1           NaN   228.0
# 41588                  0   Andres1           NaN     5.0
# 41589                  0   Andres1           NaN   191.0
# 41590                  0   Andres1           NaN     4.0
# 41591                  0   Andres1           NaN   211.0
# 41592                  0   Andres1           NaN     6.0
# 41593                  0   Andres1           NaN   193.0
# 41594                  0   Andres1           NaN     6.0
# 41595                  0   Andres1           NaN   215.0
# 41596                  0   Andres1           NaN     5.0
# 41597                  0   Andres1           NaN   210.0
# 41598                  0   Andres1           NaN     5.0
# 41599                  0   Andres1           NaN   244.0
# 41600                  0   Andres1           NaN     5.0
# 41601                  0   Andres1           NaN  1955.0
# 41602                  0   Andres1           NaN    72.0
#
# [41603 rows x 9 columns]

# %%
def getPressTypeDelta(x):
    print(x == 1)

# %%
grouped_df = df.groupby(['SessionID', 'WindowNumber']).agg({
    'PressType': {
        'Press_count': lambda x: x.count(),
    }
})
# Out:
# /Users/thicorfon/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)

# %%
filteredByPressType1 = df[df.PressType == 1].copy()
filteredByPressType0 = df[df.PressType == 0].copy()

# %%
grouped0_df = filteredByPressType0.groupby(['SessionID', 'WindowNumber']).agg({
    'Deltas': {
        'Deltas_0_mean': 'mean',
        'Deltas_0_median': 'median',
        'Deltas_0_std': 'std'
    }
})
# Out:
# /Users/thicorfon/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)

# %%
grouped1_df = filteredByPressType1.groupby(['SessionID', 'WindowNumber']).agg({
    'Deltas': {
        'Deltas_1_mean': 'mean',
        'Deltas_1_median': 'median',
        'Deltas_1_std': 'std'
    }
})
# Out:
# /Users/thicorfon/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)

# %%
features = grouped_df.merge(grouped0_df, left_index=True, right_index=True).merge(grouped1_df, left_index=True, right_index=True)

# %%
features.columns = features.columns.droplevel()

# %%
features = features.reset_index()

# %%
features
# Out:
#     SessionID  WindowNumber  Press_count  Deltas_0_mean  Deltas_0_median  \
# 0     Andres1           0.0            5     585.000000            585.0
# 1     Andres1           1.0           16    2251.000000            722.0
# 2     Andres1           2.0           26     639.076923            539.0
# 3     Andres1           3.0            7    2486.000000            465.5
# 4     Andres1           4.0           38     462.631579            334.0
# 5     Andres1           5.0           37     478.777778            396.0
# 6     Andres1           6.0           28     624.142857            597.0
# 7     Andres1           7.0           32     598.812500            426.0
# 8     Andres1           8.0           30     406.733333            418.0
# 9     Andres1          12.0            6   14257.666667            943.0
# 10    Andres1          13.0           22     821.272727            467.0
# 11    Andres1          14.0           42     423.095238            339.0
# 12    Andres1          15.0           28     652.214286            457.5
# 13    Andres1          16.0           18     549.666667            203.0
# 14    Andres1          19.0           12    5604.333333            507.5
# 15    Andres1          20.0           32     634.625000            474.5
# 16    Andres1          21.0           22     705.636364            442.0
# 17    Andres1          25.0           28    2939.642857            419.5
# 18    Andres1          26.0           14     753.857143            790.0
# 19    Andres1          27.0           18    1471.888889            398.0
# 20    Andres1          28.0           32     581.750000            424.0
# 21    Andres1          29.0           30     577.400000            434.0
# 22    Andres1          30.0           12    1648.333333           1543.0
# 23    Andres1          31.0           24     779.333333            464.0
# 24    Andres1          33.0           20    1697.700000            317.0
# 25    Andres1          34.0           52     416.346154            218.5
# 26    Andres1          35.0           32     573.750000            405.0
# 27    Andres1          36.0           18     783.666667            300.0
# 28    Andres1          37.0           22     874.454545            527.0
# 29    Andres1          39.0           22    1982.181818            385.0
# ..        ...           ...          ...            ...              ...
# 516       jo4           6.0           86     163.860465            131.0
# 517       jo4           7.0           68     248.852941            193.0
# 518       jo4           8.0           84     168.047619            155.0
# 519       jo4           9.0           85     170.697674            140.0
# 520       jo4          10.0           39     452.473684            156.0
# 521       jo4          11.0           74     179.027027            158.0
# 522       jo4          12.0           57     354.620690            157.0
# 523       jo4          13.0           96     162.312500            139.5
# 524       jo4          14.0           94     152.978723            135.0
# 525       jo4          15.0           94     144.978723            124.0
# 526       jo4          16.0           84     212.235294            141.0
# 527       jo4          17.0           87     167.883721            150.0
# 528       jo4          18.0          107     127.000000            108.5
# 529       jo4          19.0           59     288.103448            201.0
# 530       jo4          20.0           51     317.846154            158.0
# 531       jo4          21.0           89     156.818182            125.5
# 532       jo4          22.0           47     345.166667            156.5
# 533       jo4          23.0           77     196.315789            121.5
# 534       jo4          24.0           76     200.105263            139.5
# 535       jo4          25.0           92     141.086957            131.0
# 536       jo4          26.0           24     858.916667            152.0
# 537       jo4          27.0           74     211.162162            148.0
