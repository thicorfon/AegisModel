# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
file_name = 'KeyPressEvent'
df = pd.read_csv('../Our Data Windowed/' + file_name + '.csv')

# %%
df = df[df.WindowNumber != -1]

# %%
def get_deltas(df):
    deltas = []
    ultimo0 = 0
    ultimo1 = 0
    found0 = False
    found1 = False
    for _,row in df.iterrows():
        currentSystime = row.Systime
        if row.PressType == 0:
            if found1:
                deltas.append(currentSystime-ultimo1)
            else:
                deltas.append(None)
            ultimo0 = currentSystime
            found0 = True
        elif row.PressType == 1:
            if found0:
                deltas.append(currentSystime-ultimo0)
            else:
                deltas.append(None)
            ultimo1 = currentSystime
            found1 = True
    return deltas

# %%
aux = []
for session in df.SessionID.unique():
    aux += get_deltas(df[df.SessionID == session])
    print(session)
df['Deltas'] = aux
# Out:
# jo10
# jo9
# jo7
# oscar1
# Jo1
# jo6
# jo8
# Toto11
# Diego08
# Diego06
# Toto10
# Diego07
# Diego09
# Toto8
# Toto1
# Toto6
# Toto7
# Toto9
# Diego10
# jo3
# jo4
# jo5
# jo2
# Diego05
# Diego02
# Pedro1
# Toto12
# Diego03
# Diego04
# Carlos1
# Toto5
# Toto2
# Andres1

# %%
df
# Out:
#              Systime  PressTime  PressType ActivityID  KeyID  \
# 0      1542595221954        NaN          0       jo10    112
# 1      1542595222067        NaN          1       jo10    112
# 2      1542595222173        NaN          0       jo10     97
# 3      1542595222247        NaN          1       jo10     97
# 4      1542595222819        NaN          0       jo10    114
# 5      1542595222922        NaN          1       jo10    114
# 6      1542595222993        NaN          0       jo10     97
# 7      1542595223098        NaN          1       jo10     97
# 8      1542595223162        NaN          0       jo10     32
# 9      1542595223169        NaN          1       jo10     32
# 10     1542595223418        NaN          0       jo10    117
# 11     1542595223515        NaN          1       jo10    117
# 12     1542595223552        NaN          0       jo10    115
# 13     1542595223611        NaN          1       jo10    115
# 14     1542595223749        NaN          0       jo10     97
# 15     1542595223831        NaN          1       jo10     97
# 16     1542595224060        NaN          0       jo10    114
# 17     1542595224143        NaN          1       jo10    114
# 18     1542595224191        NaN          0       jo10     32
# 19     1542595224200        NaN          1       jo10     32
# 20     1542595224486        NaN          0       jo10    111
# 21     1542595224579        NaN          1       jo10    111
# 22     1542595224778        NaN          0       jo10     32
# 23     1542595224789        NaN          1       jo10     32
# 24     1542595224935        NaN          0       jo10    115
# 25     1542595225046        NaN          1       jo10    115
# 26     1542595225117        NaN          0       jo10    109
# 27     1542595225224        NaN          1       jo10    109
# 28     1542595225285        NaN          0       jo10     97
# 29     1542595225426        NaN          1       jo10     97
# ...              ...        ...        ...        ...    ...
# 91333  1541942061772        NaN          0    Andres1     46
# 91334  1541942061868        NaN          1    Andres1     46
# 91335  1541942062094        NaN          0    Andres1     32
# 91336  1541942062100        NaN          1    Andres1     32
# 91337  1541942064096        NaN          0    Andres1     -1
# 91338  1541942064182        NaN          1    Andres1     -1
# 91339  1541942064595        NaN          0    Andres1     97
# 91340  1541942064670        NaN          1    Andres1     97
# 91341  1541942064850        NaN          0    Andres1    113
# 91342  1541942064931        NaN          1    Andres1    113
# 91343  1541942065354        NaN          0    Andres1    117
# 91344  1541942065434        NaN          1    Andres1    117
# 91345  1541942066508        NaN          0    Andres1     -5
# 91346  1541942066513        NaN          1    Andres1     -5
# 91347  1541942066781        NaN          0    Andres1     -5
# 91348  1541942066787        NaN          1    Andres1     -5
# 91349  1541942068610        NaN          0    Andres1     -1
# 91350  1541942068693        NaN          1    Andres1     -1
# 91351  1541942069442        NaN          0    Andres1    113
# 91352  1541942069514        NaN          1    Andres1    113
# 91353  1541942070045        NaN          0    Andres1    117
# 91354  1541942070119        NaN          1    Andres1    117
# 91355  1541942070259        NaN          0    Andres1    105
# 91356  1541942070357        NaN          1    Andres1    105
# 91357  1541942070996        NaN          0    Andres1     32
# 91358  1541942071003        NaN          1    Andres1     32
# 91359  1541942071415        NaN          0    Andres1    110
# 91360  1541942071499        NaN          1    Andres1    110
# 91361  1541942071728        NaN          0    Andres1    111
# 91362  1541942071831        NaN          1    Andres1    111
#
#        Phone_orientation SessionID  WindowNumber  Deltas
# 0                      0      jo10             0     NaN
# 1                      0      jo10             0   113.0
# 2                      0      jo10             0   106.0
# 3                      0      jo10             0    74.0
# 4                      0      jo10             0   572.0
# 5                      0      jo10             0   103.0
# 6                      0      jo10             0    71.0
# 7                      0      jo10             0   105.0
# 8                      0      jo10             0    64.0
# 9                      0      jo10             0     7.0
# 10                     0      jo10             0   249.0
# 11                     0      jo10             0    97.0
# 12                     0      jo10             0    37.0
# 13                     0      jo10             0    59.0
# 14                     0      jo10             0   138.0
# 15                     0      jo10             0    82.0
# 16                     0      jo10             0   229.0
# 17                     0      jo10             0    83.0
# 18                     0      jo10             0    48.0
# 19                     0      jo10             0     9.0
# 20                     0      jo10             0   286.0
# 21                     0      jo10             0    93.0
# 22                     0      jo10             0   199.0
# 23                     0      jo10             0    11.0
# 24                     0      jo10             0   146.0
# 25                     0      jo10             0   111.0
# 26                     0      jo10             0    71.0
# 27                     0      jo10             0   107.0
# 28                     0      jo10             0    61.0
# 29                     0      jo10             0   141.0
# ...                  ...       ...           ...     ...
# 91333                  0   Andres1            53   902.0
# 91334                  0   Andres1            53    96.0
# 91335                  0   Andres1            53   226.0
# 91336                  0   Andres1            53     6.0
# 91337                  0   Andres1            53  1996.0
# 91338                  0   Andres1            53    86.0
# 91339                  0   Andres1            53   413.0
# 91340                  0   Andres1            53    75.0
# 91341                  0   Andres1            53   180.0
# 91342                  0   Andres1            54    81.0
# 91343                  0   Andres1            54   423.0
# 91344                  0   Andres1            54    80.0
# 91345                  0   Andres1            54  1074.0
# 91346                  0   Andres1            54     5.0
# 91347                  0   Andres1            54   268.0
# 91348                  0   Andres1            54     6.0
# 91349                  0   Andres1            54  1823.0
# 91350                  0   Andres1            54    83.0
# 91351                  0   Andres1            54   749.0
# 91352                  0   Andres1            54    72.0
# 91353                  0   Andres1            54   531.0
# 91354                  0   Andres1            54    74.0
# 91355                  0   Andres1            54   140.0
# 91356                  0   Andres1            54    98.0
# 91357                  0   Andres1            54   639.0
# 91358                  0   Andres1            54     7.0
# 91359                  0   Andres1            54   412.0
# 91360                  0   Andres1            54    84.0
# 91361                  0   Andres1            54   229.0
# 91362                  0   Andres1            54   103.0
#
# [90176 rows x 9 columns]

# %%
def getPressTypeDelta(x):
    print(x == 1)

# %%
grouped_df = df.groupby(['SessionID', 'WindowNumber']).agg({
    'PressType': {
        'Press_count': lambda x: x.count(),
    }
})
# Out:
# /Users/thicorfon/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)

# %%
filteredByPressType1 = df[df.PressType == 1].copy()
filteredByPressType0 = df[df.PressType == 0].copy()

# %%
grouped0_df = filteredByPressType0.groupby(['SessionID', 'WindowNumber']).agg({
    'Deltas': {
        'Deltas_0_mean': 'mean',
        'Deltas_0_median': 'median',
        'Deltas_0_std': 'std'
    }
})
# Out:
# /Users/thicorfon/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)

# %%
grouped1_df = filteredByPressType1.groupby(['SessionID', 'WindowNumber']).agg({
    'Deltas': {
        'Deltas_1_mean': 'mean',
        'Deltas_1_median': 'median',
        'Deltas_1_std': 'std'
    }
})
# Out:
# /Users/thicorfon/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)

# %%
features = grouped_df.merge(grouped0_df, left_index=True, right_index=True).merge(grouped1_df, left_index=True, right_index=True)

# %%
features.columns = features.columns.droplevel()

# %%
features = features.reset_index()

# %%
features
# Out:
#      SessionID  WindowNumber  Press_count  Deltas_0_mean  Deltas_0_median  \
# 0      Andres1             0            6     585.000000            585.0
# 1      Andres1             1           16    2251.000000            722.0
# 2      Andres1             2           26     639.076923            539.0
# 3      Andres1             3            7    2486.000000            465.5
# 4      Andres1             4           38     462.631579            334.0
# 5      Andres1             5           37     478.777778            396.0
# 6      Andres1             6           28     624.142857            597.0
# 7      Andres1             7           32     598.812500            426.0
# 8      Andres1             8           30     406.733333            418.0
# 9      Andres1            12            6   14257.666667            943.0
# 10     Andres1            13           22     821.272727            467.0
# 11     Andres1            14           42     423.095238            339.0
# 12     Andres1            15           28     652.214286            457.5
# 13     Andres1            16           18     549.666667            203.0
# 14     Andres1            19           12    5604.333333            507.5
# 15     Andres1            20           32     634.625000            474.5
# 16     Andres1            21           22     705.636364            442.0
# 17     Andres1            25           28    2939.642857            419.5
# 18     Andres1            26           14     753.857143            790.0
# 19     Andres1            27           18    1471.888889            398.0
# 20     Andres1            28           32     581.750000            424.0
# 21     Andres1            29           30     577.400000            434.0
# 22     Andres1            30           12    1648.333333           1543.0
# 23     Andres1            31           24     779.333333            464.0
# 24     Andres1            33           20    1697.700000            317.0
# 25     Andres1            34           52     416.346154            218.5
# 26     Andres1            35           32     573.750000            405.0
# 27     Andres1            36           18     783.666667            300.0
# 28     Andres1            37           22     874.454545            527.0
# 29     Andres1            39           22    1982.181818            385.0
# ...        ...           ...          ...            ...              ...
# 1140       jo9            34           86     163.837209            119.0
# 1141       jo9            35           64     255.437500            137.0
# 1142       jo9            36           84     174.238095            141.5
# 1143       jo9            37           78     199.307692            138.0
# 1144       jo9            38           81     177.829268            127.0
# 1145       jo9            39          103     126.576923            101.0
# 1146       jo9            40           82     184.829268            127.0
# 1147       jo9            41           88     151.272727            121.0
# 1148       jo9            42           76     200.342105            111.5
# 1149       jo9            43           99     140.080000            138.5
# 1150       jo9            44           88     157.977273            119.5
# 1151       jo9            45           86     148.348837            108.0
# 1152       jo9            46           88     182.022727            138.5
# 1153       jo9            47           84     178.047619            135.5
# 1154       jo9            48           86     162.232558            137.0
# 1155       jo9            49           94     146.425532            125.0
# 1156    oscar1             0           51     345.640000            123.0
# 1157    oscar1             1           41     650.818182            190.0
# 1158    oscar1             2           34     503.705882            182.0
# 1159    oscar1             3           42     289.714286            203.0
# 1160    oscar1             4           68     353.823529            133.5
# 1161    oscar1             5           36     430.055556            289.0
# 1162    oscar1             6           76     183.842105            148.0
# 1163    oscar1             7           30     532.533333            145.0
# 1164    oscar1             9           14    1952.285714            313.0
